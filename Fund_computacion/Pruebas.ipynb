# %% [markdown]
# Ejemplo graficación
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
# url: https://formaprogramada.wordpress.com/2017/04/21/registros-de-una-elipse/

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *

x = np.arange(-10,10,5)
num_segmentos = 300
angulo = np.linspace(0, 2*np.pi, num_segmentos)
##r = (1-np.exp(1)**2)/(1+np.exp(1)*np.cos(angulo))
ax = (np.cos(angulo))**2 
ay = (np.sin(angulo))**2
y = 1 / np.sqrt(ax/5 + ay/3)

plt.plot(y)
plt.plot(0,0,"o")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Proof graphics')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.add_patch(
    patches.Ellipse(
        (0.5, 0.5),   # (x,y)
        0.6,          # width
        0.5,          # height
    )
)

# fig1.savefig('ellipse1.png', dpi=90, bbox_inches='tight')
plt.show()

# %%
class Num():
  numero : int

def ins_num(nume : Num):
  return(f"Numero {nume.numero} insertado")
print(ins_num(4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-177452d21a9d> in <cell line: 6>()
#       4 def ins_num(nume : Num):
#       5   return(f"Numero {nume.numero} insertado")
# ----> 6 print(ins_num(4))
#
# <ipython-input-1-177452d21a9d> in ins_num(nume)
#       3
#       4 def ins_num(nume : Num):
# ----> 5   return(f"Numero {nume.numero} insertado")
#       6 print(ins_num(4))
#
# AttributeError: 'int' object has no attribute 'numero'
