# %% [markdown]
# # Las Tuplas
# Son unas colecciones de de datos (arreglos), con la característica de que son inmutables. Se definen con los datos separados por comas dentro de unos paréntesis.

# %%
tupla = (3.14,"cadena",[10,20,30],-5)

# %%
tupla
# Out:
# (3.14, 'cadena', [10, 20, 30], -5)

# %% [markdown]
# ## Indexación y slicing

# %%
tupla[0]
# Out:
# 3.14

# %%
tupla[-1]
# Out:
# -5

# %%
tupla[1:]
# Out:
# ('cadena', [10, 20, 30], -5)

# %%
tupla[2][-2]
# Out:
# 20

# %% [markdown]
# ## Inmutabilidad

# %%
tupla[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e9815587379a> in <cell line: 1>()
# ----> 1 tupla[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Función len()

# %%
len(tupla)
# Out:
# 4

# %%
len(tupla[2])
# Out:
# 3

# %% [markdown]
# ## Métodos integrados
# ### **index()**, sirve para buscar un elemento y saber su posición en la tupla. Da error si no se encuentra.

# %%
tupla
# Out:
# (3.14, 'cadena', [10, 20, 30], -5)

# %%
tupla.index("cadena")
# Out:
# 1

# %%
tupla.index(-5)
# Out:
# 3

# %%
tupla.index(15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0636bf871c72> in <cell line: 1>()
# ----> 1 tupla.index(15)
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# ### **count()**, sirve para contar cuantas veces aparece un elemento en una tupla.

# %%
tupla.count(3.14)
# Out:
# 1

# %%
tupla.count(15)
# Out:
# 0

# %%
tupla = (6,6,6,4,6,9)

# %%
tupla.count(6)
# Out:
# 4

# %% [markdown]
# ### append() ?
# Al ser inmutables, las tuplas no disponen de métodos para modificar su contenido.

# %%
tupla.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-c2e965c14a57> in <cell line: 1>()
# ----> 1 tupla.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'
