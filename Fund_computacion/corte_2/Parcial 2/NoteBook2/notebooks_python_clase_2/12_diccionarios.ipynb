# %% [markdown]
# # Los diccionarios
# Son junto a las listas las colecciones más utilizadas. Se basan en una estructura mapeada donde cada elemento de la colección se encuentra identificado con una clave única. Por tanto, no puede haber dos claves iguales. En otros lenguajes se conocen como arreglos asociativos.

# %%
vacio = {}

# %%
vacio
# Out:
# {}

# %% [markdown]
# ### Tipo de una variable

# %%
type(vacio)
# Out:
# dict

# %% [markdown]
# ## Definición
# ### Para cada elemento se define la estructura -> clave:valor

# %%
colores = {"amarillo":"yellow","azul":"blue","rojo":"red"}

# %% [markdown]
# ### También se pueden añadir elementos sobre la marcha

# %%
colores['verde'] = 'green'

# %%
colores
# Out:
# {'amarillo': 'yellow', 'azul': 'blue', 'rojo': 'red', 'verde': 'green'}

# %%
colores["azul"]
# Out:
# 'blue'

# %%
colores['amarillo']
# Out:
# 'yellow'

# %% [markdown]
# ### Función del()
# Sirve para borrar un elemento del diccionario.

# %%
del(colores['verde'])

# %%
colores
# Out:
# {'amarillo': 'yellow', 'azul': 'blue', 'rojo': 'red'}

# %% [markdown]
# ### Modificación de valor a partir de la clave

# %%
colores['amarillo'] = 'white'

# %%
colores
# Out:
# {'amarillo': 'white', 'azul': 'blue', 'rojo': 'red'}

# %% [markdown]
# ### Las claves también pueden ser números, pero son un poco confusas

# %%
numeros = {5:"cinco",15:"quince"}

# %%
numeros[15]
# Out:
# 'quince'

# %% [markdown]
# ### Trabajando directamente con registros

# %%
notas = {"Luis":3.5,"Carolina":4.0,"Maria":2.0}

# %%
notas
# Out:
# {'Luis': 3.5, 'Carolina': 4.0, 'Maria': 2.0}

# %%
notas["Luis"] += 0.1

# %%
notas
# Out:
# {'Luis': 3.7, 'Carolina': 4.0, 'Maria': 2.0}

# %%
notas["Carolina"] + notas["Maria"]
# Out:
# 6.0

# %% [markdown]
# ## Lectura secuencial con for .. in ..
# Es posible utilizar una iteración for para recorrer los elementos del diccionario:

# %%
for elemento in notas:
    print(elemento)
# Out:
# Luis
# Carolina
# Maria

# %% [markdown]
# ### El problema es que se devuelven las claves, no los valores
# Para solucionarlo deberíamos indicar la clave del diccionario para cada elemento.

# %%
for claves in notas:
    print(notas[claves])
# Out:
# 3.7
# 4.0
# 2.0

# %%
for clave in edades:
    print(clave,edades[clave])
# Out:
# Hector 29
# Juan 45
# Maria 34
# david 40

# %% [markdown]
# ### El método .items()
# Nos facilita la lectura en clave y valor de los elementos porque devuelve ambos valores en cada iteración automáticamente:

# %%
for claves,valores in notas.items():
    print(claves,valores)
# Out:
# Luis 3.7
# Carolina 4.0
# Maria 2.0

# %% [markdown]
# ## **Ejemplo:** utilizando diccionarios y listas a la vez para crear una base de datos
# Podemos crear nuestras propias estructuras avanzadas mezclando ambas colecciones. Mientras los diccionarios se encargarían de manejar las propiedades individuales de los registros, las listas nos permitirían manejarlos todos en conjunto.

# %%
liga_de_la_justicia = []

heroe = {"nombre":"Superman","poder":"Volar","origen":"Kripton"}
liga_de_la_justicia.append(heroe)
heroe = {"nombre":"Batman","poder":"Ninguno","origen":"Tierra"}
liga_de_la_justicia.append(heroe)
heroe = {"nombre":"Mujer maravilla","poder":"Súper fuerza","origen":"Tierra"}
liga_de_la_justicia.append(heroe)

print(liga_de_la_justicia)
print()
print(liga_de_la_justicia[0]["nombre"])
print()

for heroes in liga_de_la_justicia:
    print(heroes["nombre"],heroes["poder"],heroes["origen"])
# Out:
# [{'nombre': 'Superman', 'poder': 'Volar', 'origen': 'Kripton'}, {'nombre': 'Batman', 'poder': 'Ninguno', 'origen': 'Tierra'}, {'nombre': 'Mujer maravilla', 'poder': 'Súper fuerza', 'origen': 'Tierra'}]
#
# Superman
#
# Superman Volar Kripton
# Batman Ninguno Tierra
# Mujer maravilla Súper fuerza Tierra
