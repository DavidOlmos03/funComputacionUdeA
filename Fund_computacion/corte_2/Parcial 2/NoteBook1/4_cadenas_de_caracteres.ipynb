# %% [markdown]
# # Textos (cadenas de caracteres)

# %%
'Hola Mundo'
# Out:
# 'Hola Mundo'

# %%
"Hola Mundo"
# Out:
# 'Hola Mundo'

# %%
'Este texto incluye unas "comillas dobles" '
# Out:
# 'Este texto incluye unas "comillas dobles" '

# %%
"Esta 'palabra' se encuentra escrita entre comillas simples"
# Out:
# "Esta 'palabra' se encuentra escrita entre comillas simples"

# %%
"Esta \"palabra\" se encuentra escrita entre comillas dobles"
# Out:
# 'Esta "palabra" se encuentra escrita entre comillas dobles'

# %%
'Esta \'palabra\' se encuentra escrita entre comillas simples'
# Out:
# "Esta 'palabra' se encuentra escrita entre comillas simples"

# %% [markdown]
# ## La función print()
# Es una instrucción que nos permite mostrar correctamente el valor de una cadena (u otros valores/variables) por pantalla.

# %%
"Una cadena"
'otra cadena'
'otra cadena más.'
# Out:
# 'otra cadena más.'

# %%
print("Una cadena")
print('otra cadena')
print('otra cadena más.')
# Out:
# Una cadena
# otra cadena
# otra cadena más.

# %% [markdown]
# #### Acepta carácteres especiales como las tabulaciones \t o los saltos de línea \n, estos se llaman secuncias de escape.

# %%
print("Un texto\tuna tabulación")
# Out:
# Un texto	una tabulación

# %%
print("Un texto\nuna nueva línea")
# Out:
# Un texto
# una nueva línea

# %% [markdown]
# #### Para evitar los carácteres especiales, debemos indicar que una cadena es cruda (raw)

# %%
print("C:\nombre\directorio")
# Out:
# C:
# ombre\directorio

# %%
print(r"C:\nombre\directorio")  # r => raw (cruda)
# Out:
# C:\nombre\directorio

# %% [markdown]
# #### Podemos utilizar """ *(triple comillas)* para cadenas multilínea

# %%
print("""Una línea 
otra línea 
otra línea\tuna tabulación""")
# Out:
# Una línea
# otra línea
# otra línea	una tabulación

# %% [markdown]
# #### También es posible asignar cadenas a variables
# La forma correcta de mostrarlas es con la instrucción print().

# %%
c = "Esto es una cadena\ncon dos líneas"

# %%
c
# Out:
# 'Esto es una cadena\ncon dos líneas'

# %%
print(c)
# Out:
# Esto es una cadena
# con dos líneas

# %% [markdown]
# ## Operaciones
# Una de las operaciones de las cadenas es la concatenación (o suma de cadenas).

# %%
c + c
# Out:
# 'Esto es una cadena\ncon dos líneas Esto es una cadena\ncon dos líneas'

# %%
print(c+c)
# Out:
# Esto es una cadena
# con dos líneasEsto es una cadena
# con dos líneas

# %%
s = "Una cadena" " compuesta de dos cadenas"
print(s)
# Out:
# Una cadena compuesta de dos cadenas

# %%
c1 = "Una cadena"
c2 = "otra cadena"
print("Una cadena " + c2)
# Out:
# Una cadena otra cadena

# %% [markdown]
# #### También es posible utilizar la multiplicación de cadenas para replicar cadenas o caracteres.

# %%
ocho_espacios = "ma" *8
print(ocho_espacios + "un texto a 8 espacios")
# Out:
# mamamamamamamamaun texto a 8 espacios

# %% [markdown]
# ## Índices en las cadenas
# Los índices nos permiten posicionarnos en un carácter específico de una cadena.
#
# Representan un número [índice], que empezando por el 0 indica el carácter de la primera posición, y así sucesivamente. Realmente son desplazamientos en memoria RAM.

# %%
palabra = "Python"

# %%
palabra[0] # carácter en la posición 0
# Out:
# 'P'

# %%
palabra[3]
# Out:
# 'h'

# %% [markdown]
# #### El índice negativo -1, hace referencia al carácter de la última posición, el -2 al penúltimo y así sucesivamente. Permite acceder a las componentes de las cadenas de atras hacia adelante.

# %%
palabra[-1]
# Out:
# 'n'

# %%
palabra[-0]
# Out:
# 'P'

# %%
palabra[-2]
# Out:
# 'o'

# %%
palabra[-6]
# Out:
# 'P'

# %%
palabra[5]
# Out:
# 'n'

# %% [markdown]
# ## Slicing en las cadenas
# El slicing es una capacidad de las cadenas que devuelve un subconjunto o subcadena utilizando dos índices [inicio:fin]:
# - El primer índice indica donde empieza la subcadena (se incluye el carácter).
# - El segundo índice indica donde acaba la subcadena (se excluye el carácter).

# %%
palabra = "Python"

# %%
palabra[1:4]
# Out:
# 'yth'

# %%
palabra[2:]
# Out:
# 'thon'

# %%
palabra[:2]
# Out:
# 'Py'

# %% [markdown]
# #### Si en el slicing no se indica un índice se toma por defecto el principio y el final (incluídos).

# %%
palabra[:]
# Out:
# 'Python'

# %%
palabra[:2] + palabra[2:]
# Out:
# 'Python'

# %%
palabra[-2:]
# Out:
# 'on'

# %% [markdown]
# #### Si un índice se encuentra fuera del rango de la cadena, se genera error

# %%
palabra[99]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-5e2153d06ee5> in <module>
# ----> 1 palabra[99]
#
# IndexError: string index out of range

# %% [markdown]
# #### Pero con slicing ésto no pasa y simplemente se ignoran los espacios sin caracteres

# %%
palabra[:99]
# Out:
# 'Python'

# %%
palabra[99:]
# Out:
# ''

# %% [markdown]
# ## Inmutabilidad
# Una propiedad de las cadenas es que no se pueden modificar. Si intentamos reasignar un carácter, no nos dejará:

# %%
palabra[0] = "N"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-59c3697fa6c2> in <module>
# ----> 1 palabra[0] = "N"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# #### Sin embargo, utilizando slicing y concatenación podemos generar nuevas cadenas fácilmente:

# %%
palabra = "N" + palabra[1:]
palabra
# Out:
# 'Nython'

# %% [markdown]
# ### Funciones
# Un ejemplo de función que operan sobre las cadenas es len(), que nos permite saber su longitud (el número de caracteres que contienen).

# %%
len(palabra)
# Out:
# 6

# %% [markdown]
# #### Hay más funciones, pero las iremos descubriendo a lo largo del curso.
