# %% [markdown]
# ## **Operaciones aritméticas**
# ## El intérprete de Python se puede usar como una calculadora muy precisa.

# %%
2+5
# Out:
# 7

# %%
2-5
# Out:
# -3

# %%
2*5
# Out:
# 10

# %%
2*5.0
# Out:
# 10.0

# %% [markdown]
# ## Con # podemos escirbir comentarios en el código, estos no se interporetan como instricciones y no se ejecutan

# %%
# División
2/5
# Out:
# 0.4

# %%
# Módulo
5%2
# Out:
# 1

# %%
# Potencia
5**2
# Out:
# 25

# %% [markdown]
# ## Python maneja dos tipos de números: enteros y flotantes.

# %%
# Enteros
8
# Out:
# 8

# %%
# Flotantes
3.141628
# Out:
# 3.141628

# %% [markdown]
# ### En las operaciones más complejas Python se guía por la predecencia de operaciones
#
# 1. Primero los paréntesis porque tienen prioridad
# 2. Segundo, las expresiones aritméticas por sus propias reglas
# 3. Tercero, las expresiones relacionales
# 4. Cuarto, las expresiones lógicas

# %%
30/10*2
# Out:
# 6.0

# %%
30/(10*2)
# Out:
# 1.5

# %%
180/6-3*4*8-6-30/10*2
# Out:
# -78.0

# %%
180/6-3*(4*(8-6)-30/10*2)
# Out:
# 24.0

# %% [markdown]
# ## **variables**
#
# La variables se caracterizan por 3 propiedades:
#
#
#
# 1.   Un símbolo (para el programador).
# 2.   Un valor.
# 3.   Una dirección en memoria RAM.
#
# Nota: en Python las variables se definen cuando se usan por primera vez, sus valores de pueden re-asignar y hacer álgebra con ellas.

# %%
# definamos y asignemos (=) un valor a una variable
x = 10
x = x + 4
x
# Out:
# 14

# %%
# uso de la variable sin cambiar su valor
x+5
# Out:
# 19

# %%
x*2
# Out:
# 28

# %%
x*x
# Out:
# 196

# %%
t = 8

# %%
# Álgebra
x+t
# Out:
# 22

# %%
x*t+8
# Out:
# 120

# %%
# Re-asignación
x=7
t=5
x+t
# Out:
# 12

# %%
x=t

# %%
x
# Out:
# 5

# %%
t
# Out:
# 5

# %%
x=t+3

# %%
x
# Out:
# 8

# %%
x=x+10

# %%
x
# Out:
# 38

# %% [markdown]
# **Tener cuidado con el orden con el que se ejecutan las celdas para trabajar con los valores correctos.** Es mejor siempre reiniciar el kernel para asegurarse de usar bien los valores almacenados en variables.
